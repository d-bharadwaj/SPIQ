# %%
import numpy as np
import qubovert

import pcbo_utils

# %%
feature_set, feature_to_idx, first_corr_arr, second_corr_arr, third_corr_arr = pcbo_utils.load_features_and_corr_files('sampled_8_features_subproblem_1')

# %%
pcbo_obj = pcbo_utils.create_three_body_cubo(
    feature_set,
    first_corr_arr,
    second_corr_arr,
    third_corr_arr,
    feature_to_idx,
    select_n_features=4,
)

# %%
pcbo_obj
# Out:
# {('mRNA-PLOD3',): -7000.3674775052195,
#  ('mRNA-PLEKHJ1',): -7000.267076428868,
#  ('mRNA-PVT1',): -7000.307541747743,
#  ('mRNA-CORO6',): -7000.25933123445,
#  ('mRNA-CRLF2',): -7000.135348848076,
#  ('mRNA-PELO',): -7000.279097862935,
#  ('mRNA-MYBPHL',): -7000.228416693991,
#  ('mRNA-ETV6',): -7000.336547331394,
#  ('mRNA-PLEKHJ1', 'mRNA-PLOD3'): 1999.2185965776443,
#  ('mRNA-PLOD3', 'mRNA-PVT1'): 1999.2137832045555,
#  ('mRNA-CORO6', 'mRNA-PLOD3'): 1999.3369145393372,
#  ('mRNA-CRLF2', 'mRNA-PLOD3'): 1999.442137479782,
#  ('mRNA-PELO', 'mRNA-PLOD3'): 1999.3472903966904,
#  ('mRNA-MYBPHL', 'mRNA-PLOD3'): 1999.3045518994331,
#  ('mRNA-ETV6', 'mRNA-PLOD3'): 1999.1254116892815,
#  ('mRNA-PLEKHJ1', 'mRNA-PVT1'): 1999.2033087611198,
#  ('mRNA-CORO6', 'mRNA-PLEKHJ1'): 1999.343507885933,
#  ('mRNA-CRLF2', 'mRNA-PLEKHJ1'): 1999.5179376006126,
#  ('mRNA-PELO', 'mRNA-PLEKHJ1'): 1999.3267159461975,
#  ('mRNA-MYBPHL', 'mRNA-PLEKHJ1'): 1999.4111328721046,
#  ('mRNA-ETV6', 'mRNA-PLEKHJ1'): 1999.251591682434,
#  ('mRNA-CORO6', 'mRNA-PVT1'): 1999.3073891997337,
#  ('mRNA-CRLF2', 'mRNA-PVT1'): 1999.5096174180508,
#  ('mRNA-PELO', 'mRNA-PVT1'): 1999.3207090497017,
#  ('mRNA-MYBPHL', 'mRNA-PVT1'): 1999.3833955526352,
#  ('mRNA-ETV6', 'mRNA-PVT1'): 1999.3365607857704,
#  ('mRNA-CORO6', 'mRNA-CRLF2'): 1999.5550712943077,
#  ('mRNA-CORO6', 'mRNA-PELO'): 1999.3004924058914,
#  ('mRNA-CORO6', 'mRNA-MYBPHL'): 1999.3958300352097,
#  ('mRNA-CORO6', 'mRNA-ETV6'): 1999.2366761565208,
#  ('mRNA-CRLF2', 'mRNA-PELO'): 1999.5729429721832,
#  ('mRNA-CRLF2', 'mRNA-MYBPHL'): 1999.6087684631348,
#  ('mRNA-CRLF2', 'mRNA-ETV6'): 1999.4693656563759,
#  ('mRNA-MYBPHL', 'mRNA-PELO'): 1999.3980821371078,
#  ('mRNA-ETV6', 'mRNA-PELO'): 1999.353120625019,
#  ('mRNA-ETV6', 'mRNA-MYBPHL'): 1999.3126233816147,
#  ('mRNA-PLEKHJ1', 'mRNA-PLOD3', 'mRNA-PVT1'): 0.45987337827682495,
#  ('mRNA-CORO6', 'mRNA-PLEKHJ1', 'mRNA-PLOD3'): 0.5295138359069824,
#  ('mRNA-CRLF2', 'mRNA-PLEKHJ1', 'mRNA-PLOD3'): 0.24414947628974915,
#  ('mRNA-PELO', 'mRNA-PLEKHJ1', 'mRNA-PLOD3'): 0.4047423303127289,
#  ('mRNA-MYBPHL', 'mRNA-PLEKHJ1', 'mRNA-PLOD3'): 0.39063188433647156,
#  ('mRNA-ETV6', 'mRNA-PLEKHJ1', 'mRNA-PLOD3'): 0.4363104999065399,
#  ('mRNA-CORO6', 'mRNA-PLOD3', 'mRNA-PVT1'): 0.4800085723400116,
#  ('mRNA-CRLF2', 'mRNA-PLOD3', 'mRNA-PVT1'): 0.2522815763950348,
#  ('mRNA-PELO', 'mRNA-PLOD3', 'mRNA-PVT1'): 0.5086906552314758,
#  ('mRNA-MYBPHL', 'mRNA-PLOD3', 'mRNA-PVT1'): 0.32370057702064514,
#  ('mRNA-ETV6', 'mRNA-PLOD3', 'mRNA-PVT1'): 0.3899300694465637,
#  ('mRNA-CORO6', 'mRNA-CRLF2', 'mRNA-PLOD3'): 0.24758103489875793,
#  ('mRNA-CORO6', 'mRNA-PELO', 'mRNA-PLOD3'): 0.46205759048461914,
#  ('mRNA-CORO6', 'mRNA-MYBPHL', 'mRNA-PLOD3'): 0.3829963505268097,
#  ('mRNA-CORO6', 'mRNA-ETV6', 'mRNA-PLOD3'): 0.46708473563194275,
#  ('mRNA-CRLF2', 'mRNA-PELO', 'mRNA-PLOD3'): 0.23685447871685028,
#  ('mRNA-CRLF2', 'mRNA-MYBPHL', 'mRNA-PLOD3'): 0.22346213459968567,
#  ('mRNA-CRLF2', 'mRNA-ETV6', 'mRNA-PLOD3'): 0.2111208736896515,
#  ('mRNA-MYBPHL', 'mRNA-PELO', 'mRNA-PLOD3'): 0.3800114095211029,
#  ('mRNA-ETV6', 'mRNA-PELO', 'mRNA-PLOD3'): 0.41656988859176636,
#  ('mRNA-ETV6', 'mRNA-MYBPHL', 'mRNA-PLOD3'): 0.36817964911460876,
#  ('mRNA-CORO6', 'mRNA-PLEKHJ1', 'mRNA-PVT1'): 0.5209873914718628,
#  ('mRNA-CRLF2', 'mRNA-PLEKHJ1', 'mRNA-PVT1'): 0.2979276180267334,
#  ('mRNA-PELO', 'mRNA-PLEKHJ1', 'mRNA-PVT1'): 0.49115246534347534,
#  ('mRNA-MYBPHL', 'mRNA-PLEKHJ1', 'mRNA-PVT1'): 0.4071221947669983,
#  ('mRNA-ETV6', 'mRNA-PLEKHJ1', 'mRNA-PVT1'): 0.4506511688232422,
#  ('mRNA-CORO6', 'mRNA-CRLF2', 'mRNA-PLEKHJ1'): 0.3301485776901245,
#  ('mRNA-CORO6', 'mRNA-PELO', 'mRNA-PLEKHJ1'): 0.5918329954147339,
#  ('mRNA-CORO6', 'mRNA-MYBPHL', 'mRNA-PLEKHJ1'): 0.4754401743412018,
#  ('mRNA-CORO6', 'mRNA-ETV6', 'mRNA-PLEKHJ1'): 0.5907571315765381,
#  ('mRNA-CRLF2', 'mRNA-PELO', 'mRNA-PLEKHJ1'): 0.29676055908203125,
#  ('mRNA-CRLF2', 'mRNA-MYBPHL', 'mRNA-PLEKHJ1'): 0.24606305360794067,
#  ('mRNA-CRLF2', 'mRNA-ETV6', 'mRNA-PLEKHJ1'): 0.29775023460388184,
#  ('mRNA-MYBPHL', 'mRNA-PELO', 'mRNA-PLEKHJ1'): 0.42747732996940613,
#  ('mRNA-ETV6', 'mRNA-PELO', 'mRNA-PLEKHJ1'): 0.4643487334251404,
#  ('mRNA-ETV6', 'mRNA-MYBPHL', 'mRNA-PLEKHJ1'): 0.44541633129119873,
#  ('mRNA-CORO6', 'mRNA-CRLF2', 'mRNA-PVT1'): 0.2824825048446655,
#  ('mRNA-CORO6', 'mRNA-PELO', 'mRNA-PVT1'): 0.5309921503067017,
#  ('mRNA-CORO6', 'mRNA-MYBPHL', 'mRNA-PVT1'): 0.45792877674102783,
#  ('mRNA-CORO6', 'mRNA-ETV6', 'mRNA-PVT1'): 0.5237584710121155,
#  ('mRNA-CRLF2', 'mRNA-PELO', 'mRNA-PVT1'): 0.2551785707473755,
#  ('mRNA-CRLF2', 'mRNA-MYBPHL', 'mRNA-PVT1'): 0.2688033878803253,
#  ('mRNA-CRLF2', 'mRNA-ETV6', 'mRNA-PVT1'): 0.15945997834205627,
#  ('mRNA-MYBPHL', 'mRNA-PELO', 'mRNA-PVT1'): 0.3902203440666199,
#  ('mRNA-ETV6', 'mRNA-PELO', 'mRNA-PVT1'): 0.4634159803390503,
#  ('mRNA-ETV6', 'mRNA-MYBPHL', 'mRNA-PVT1'): 0.3964804708957672,
#  ('mRNA-CORO6', 'mRNA-CRLF2', 'mRNA-PELO'): 0.30874165892601013,
#  ('mRNA-CORO6', 'mRNA-CRLF2', 'mRNA-MYBPHL'): 0.23349396884441376,
#  ('mRNA-CORO6', 'mRNA-CRLF2', 'mRNA-ETV6'): 0.2888838052749634,
#  ('mRNA-CORO6', 'mRNA-MYBPHL', 'mRNA-PELO'): 0.43983808159828186,
#  ('mRNA-CORO6', 'mRNA-ETV6', 'mRNA-PELO'): 0.4982379972934723,
#  ('mRNA-CORO6', 'mRNA-ETV6', 'mRNA-MYBPHL'): 0.39134204387664795,
#  ('mRNA-CRLF2', 'mRNA-MYBPHL', 'mRNA-PELO'): 0.1946226954460144,
#  ('mRNA-CRLF2', 'mRNA-ETV6', 'mRNA-PELO'): 0.2640964090824127,
#  ('mRNA-CRLF2', 'mRNA-ETV6', 'mRNA-MYBPHL'): 0.2092224806547165,
#  ('mRNA-ETV6', 'mRNA-MYBPHL', 'mRNA-PELO'): 0.37101200222969055,
#  (): 16000}

# %%
anneal_result = qubovert.sim.anneal_pubo(pcbo_obj.to_pubo())

# %%
anneal_result
# Out:
# [AnnealResult(state={0: 1, 1: 0, 2: 0, 3: 1, 4: 0, 5: 1, 6: 1, 7: 0}, value=-3.38626, spin=False)]
